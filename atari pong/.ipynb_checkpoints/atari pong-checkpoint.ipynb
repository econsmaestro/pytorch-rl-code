# %%
import gymnasium as gym
#create atari environment(pong as eg)
env=gym.make("ALE/Pong-v5")
#reset environemnt to make a new episode
state=env.reset()
#run random agent to see environemtn in action
for _ in range(1000):
    action=env.action_space.sample() #random action
    state,reward,done,info=env.step(action)
    env.render() #render game screen
    if done:
        break
env.close()
# Out:
# ---------------------------------------------------------------------------
# NamespaceNotFound                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import gymnasium as gym
#       2 #create atari environment(pong as eg)
# ----> 3 env=gym.make("ALE/Pong-v5")
#       4 #reset environemnt to make a new episode
#       5 state=env.reset()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\envs\registration.py:682, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     679     assert isinstance(id, str)
#     681     # The environment name can include an unloaded module in "module:env_name" style
# --> 682     env_spec = _find_spec(id)
#     684 assert isinstance(env_spec, EnvSpec)
#     686 # Update the env spec kwargs with the `make` kwargs
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\envs\registration.py:527, in _find_spec(env_id)
#     521     logger.warn(
#     522         f"Using the latest versioned environment `{new_env_id}` "
#     523         f"instead of the unversioned environment `{env_name}`."
#     524     )
#     526 if env_spec is None:
# --> 527     _check_version_exists(ns, name, version)
#     528     raise error.Error(
#     529         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     530     )
#     532 return env_spec
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\envs\registration.py:391, in _check_version_exists(ns, name, version)
#     388 if get_env_id(ns, name, version) in registry:
#     389     return
# --> 391 _check_name_exists(ns, name)
#     392 if version is None:
#     393     return
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\envs\registration.py:354, in _check_name_exists(ns, name)
#     352 """Check if an env exists in a namespace. If it doesn't, print a helpful error message."""
#     353 # First check if the namespace exists
# --> 354 _check_namespace_exists(ns)
#     356 # Then check if the name exists
#     357 names: set[str] = {
#     358     env_spec.name for env_spec in registry.values() if env_spec.namespace == ns
#     359 }
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\gymnasium\envs\registration.py:348, in _check_namespace_exists(ns)
#     345 else:
#     346     suggestion_msg = f"Have you installed the proper package for {ns}?"
# --> 348 raise error.NamespaceNotFound(f"Namespace {ns} not found. {suggestion_msg}")
#
# NamespaceNotFound: Namespace ALE not found. Have you installed the proper package for ALE?

# %%
import ale_py
import gymnasium as gym
gym.register_envs(ale_py)

env = gym.make("ALE/Pong-v5", render_mode="human")
state, info = env.reset()
print("Environment created successfully!")

for i in range(1000):
  action = env.action_space.sample()
  state, reward, terminated, truncated, info = env.step(action)
  if i % 100 == 0:
      print(f"Step {i}, reward: {reward}")
  if terminated or truncated:
      state, info = env.reset()

env.close()
print("Done!")
